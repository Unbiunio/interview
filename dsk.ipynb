# %%
pip install requests pandas matplotlib seaborn
# Out:
# Requirement already satisfied: requests in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\rafas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\rafas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
import requests

# %%
# URL del endpoint de categorías
url = "https://es-mycooktouch.group-taurus.com/categories/"

# Realiza la solicitud GET
response = requests.get(url)

# Verifica que la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Convierte la respuesta a formato JSON
    data = response.json()
    
    # Guarda el contenido en un archivo JSON
    with open('categorias.json', 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=6)
    
    print("¡Contenido guardado en categorias.json!")
else:
    print(f"Error en la solicitud. Código de estado: {response.status_code}")
# Out:
# ¡Contenido guardado en categorias.json!

# %%
# Cargar el archivo JSON
with open('categorias.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Crear un DataFrame con las características principales
df_categorias = pd.DataFrame(data, columns=[
    'name', 
    'niceName', 
    'visibility', 
    'region', 
    'count', 
    'checkedCount'
])

# Mostrar el DataFrame
df_categorias
# Out:
#                                 name               niceName  visibility  \
# 0                 Aperitivos y tapas       aperitivos-tapas        True
# 1                            Arroces                arroces        True
# 2                 Bebidas y cócteles    bebidas-y-cocktails        True
# 3                      Carnes y aves          carnes-y-aves        True
# 4             Cremas, caldos y sopas    cremas-caldos-sopas        True
# 5                Dulces y repostería    dulces-y-reposteria        True
# 6                          Ensaladas              ensaladas        True
# 7                  Funciones básicas              funciones       False
# 8                  Huevos y tarrinas      huevos-y-tarrinas        True
# 9                              Masas                  masas        True
# 10                             Otras                  otras       False
# 11  Papillas y alimentación infantil  alimentacion-infantil        True
# 12                             Pasta                  pasta        True
# 13               Pescados y mariscos    pescados-y-mariscos        True
# 14               Potajes y legumbres      potajes-legumbres        True
# 15             Salsas y guarniciones  salsas-y-guarniciones        True
# 16                Sorbetes y helados     sorbetes-y-helados        True
# 17             Verduras y hortalizas  verduras-y-hortalizas        True
# 18               Vinagretas y aliños                aceites        True
#
#             region  count  checkedCount
# 0   ES-MYCOOKTOUCH   1179           132
# 1   ES-MYCOOKTOUCH    849            58
# 2   ES-MYCOOKTOUCH    619            91
# 3   ES-MYCOOKTOUCH   1455           180
# 4   ES-MYCOOKTOUCH   1820           171
# 5   ES-MYCOOKTOUCH   5200           429
# 6   ES-MYCOOKTOUCH    175            63
# 7   ES-MYCOOKTOUCH     14            13
# 8   ES-MYCOOKTOUCH   1257           400
# 9   ES-MYCOOKTOUCH   1086           107
# 10  ES-MYCOOKTOUCH     63             1
# 11  ES-MYCOOKTOUCH    232            23
# 12  ES-MYCOOKTOUCH    716            70
# 13  ES-MYCOOKTOUCH    823           134
# 14  ES-MYCOOKTOUCH    825            53
# 15  ES-MYCOOKTOUCH   1019           110
# 16  ES-MYCOOKTOUCH    258            41
# 17  ES-MYCOOKTOUCH   1261           173
# 18  ES-MYCOOKTOUCH     59            13

# %%
import pandas as pd

import pandas as pd

def drop_constant_columns(df):
    """
    Elimina las columnas del DataFrame que tienen un único valor único.
    
    Parámetros:
        df (pd.DataFrame): El DataFrame de entrada.
    
    Retorna:
        pd.DataFrame: Un nuevo DataFrame sin las columnas constantes.
    """
    # Encontrar columnas con un único valor único
    constant_columns = [col for col in df.columns if df[col].nunique() == 1]
    
    # Eliminar las columnas constantes
    df = df.drop(columns=constant_columns)
    
    return df

# %%
# Aplicar la función a df_categorias
df_categorias = drop_constant_columns(df_categorias)


df_categorias
# Out:
#                                 name               niceName  visibility  \
# 0                 Aperitivos y tapas       aperitivos-tapas        True
# 1                            Arroces                arroces        True
# 2                 Bebidas y cócteles    bebidas-y-cocktails        True
# 3                      Carnes y aves          carnes-y-aves        True
# 4             Cremas, caldos y sopas    cremas-caldos-sopas        True
# 5                Dulces y repostería    dulces-y-reposteria        True
# 6                          Ensaladas              ensaladas        True
# 7                  Funciones básicas              funciones       False
# 8                  Huevos y tarrinas      huevos-y-tarrinas        True
# 9                              Masas                  masas        True
# 10                             Otras                  otras       False
# 11  Papillas y alimentación infantil  alimentacion-infantil        True
# 12                             Pasta                  pasta        True
# 13               Pescados y mariscos    pescados-y-mariscos        True
# 14               Potajes y legumbres      potajes-legumbres        True
# 15             Salsas y guarniciones  salsas-y-guarniciones        True
# 16                Sorbetes y helados     sorbetes-y-helados        True
# 17             Verduras y hortalizas  verduras-y-hortalizas        True
# 18               Vinagretas y aliños                aceites        True
#
#     count  checkedCount
# 0    1179           132
# 1     849            58
# 2     619            91
# 3    1455           180
# 4    1820           171
# 5    5200           429
# 6     175            63
# 7      14            13
# 8    1257           400
# 9    1086           107
# 10     63             1
# 11    232            23
# 12    716            70
# 13    823           134
# 14    825            53
# 15   1019           110
# 16    258            41
# 17   1261           173
# 18     59            13

# %%
df_categorias.drop(df_categorias[df_categorias["name"] == "Otras"].index, inplace=True)

# %%
df_categorias.drop(df_categorias[df_categorias["name"] == "Funciones básicas"].index, inplace=True)

# %%
df_categorias
# Out:
#                                 name               niceName  visibility  \
# 0                 Aperitivos y tapas       aperitivos-tapas        True
# 1                            Arroces                arroces        True
# 2                 Bebidas y cócteles    bebidas-y-cocktails        True
# 3                      Carnes y aves          carnes-y-aves        True
# 4             Cremas, caldos y sopas    cremas-caldos-sopas        True
# 5                Dulces y repostería    dulces-y-reposteria        True
# 6                          Ensaladas              ensaladas        True
# 8                  Huevos y tarrinas      huevos-y-tarrinas        True
# 9                              Masas                  masas        True
# 11  Papillas y alimentación infantil  alimentacion-infantil        True
# 12                             Pasta                  pasta        True
# 13               Pescados y mariscos    pescados-y-mariscos        True
# 14               Potajes y legumbres      potajes-legumbres        True
# 15             Salsas y guarniciones  salsas-y-guarniciones        True
# 16                Sorbetes y helados     sorbetes-y-helados        True
# 17             Verduras y hortalizas  verduras-y-hortalizas        True
# 18               Vinagretas y aliños                aceites        True
#
#     count  checkedCount
# 0    1179           132
# 1     849            58
# 2     619            91
# 3    1455           180
# 4    1820           171
# 5    5200           429
# 6     175            63
# 8    1257           400
# 9    1086           107
# 11    232            23
# 12    716            70
# 13    823           134
# 14    825            53
# 15   1019           110
# 16    258            41
# 17   1261           173
# 18     59            13

# %%
df_categorias["categorias"] = df_categorias["name"]
df_categorias = df_categorias[["categorias", "count", "visibility"]]

# %%
df_categorias
# Out:
#                           categorias  count  visibility
# 0                 Aperitivos y tapas   1179        True
# 1                            Arroces    849        True
# 2                 Bebidas y cócteles    619        True
# 3                      Carnes y aves   1455        True
# 4             Cremas, caldos y sopas   1820        True
# 5                Dulces y repostería   5200        True
# 6                          Ensaladas    175        True
# 8                  Huevos y tarrinas   1257        True
# 9                              Masas   1086        True
# 11  Papillas y alimentación infantil    232        True
# 12                             Pasta    716        True
# 13               Pescados y mariscos    823        True
# 14               Potajes y legumbres    825        True
# 15             Salsas y guarniciones   1019        True
# 16                Sorbetes y helados    258        True
# 17             Verduras y hortalizas   1261        True
# 18               Vinagretas y aliños     59        True

# %% [markdown]
# ### como tenemos 10.000 recetas extraemos 5 json de 2000 recetas y las pasamos a df con las columnas que nosotros decidamos

# %%
# URL del endpoint de recetas
url = "https://es-mycooktouch.group-taurus.com/recipes/"

# Función para extraer los datos de cada receta
def extract_recipe_data(recipe):
    recipe_data = {
        "title": recipe.get("title", ""),
        'niceName': recipe['niceName'],
        "category": recipe.get("category", ""),
        "totalTime": (recipe.get("totalTime", 0)) / 60,
        "difficulty": recipe.get("difficulty", 0),
        "price": recipe.get("price", 0),
        "ingredients": ", ".join([f"{ing.get('name', '')} ({ing.get('qty', '')} {ing.get('unit', '')})" for ing in recipe.get("ingredients", [])]),
        "steps": len(recipe.get("groups", [{}])[0].get("steps", [])) if recipe.get("groups") else 0,
        "tags": ", ".join(recipe.get("tags", [])),
    }

    groups = recipe.get("groups", [])
    if groups:
        group = groups[0]
        recipe_data["group_name"] = group.get("name", "")
        recipe_data["group_steps"] = ", ".join([step.get("description", "") for step in group.get("steps", [])])

    return recipe_data

# Crear listas para almacenar los DataFrames y los JSON
dataframes = []
json_files = []

# Bucle para obtener 5 bloques de 2000 recetas cada uno
for i in range(5):
    # Parámetros para la solicitud
    params = {
        'profile': 'desktopList',
        'limit': 2000,
        'skip': i * 2000,  # Saltar las recetas ya obtenidas
        'sortBy': 'recent'
    }

    # Realizar la solicitud POST
    response = requests.post(url, params=params)

    # Verificar si la solicitud fue exitosa
    if response.status_code == 200:
        print(f"Solicitud {i+1} exitosa!")
        data = response.json()  # Convertir la respuesta a JSON
        
        # Guardar el JSON en un archivo
        json_filename = f"recetas_{i+1}.json"
        with open(json_filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4, ensure_ascii=False)
        json_files.append(json_filename)
        
        # Procesar todas las recetas
        recipes_data = [extract_recipe_data(recipe) for recipe in data["result"]]

        # Crear el DataFrame
        df = pd.DataFrame(recipes_data)
        dataframes.append(df)

        # Crear una variable global para cada DataFrame
        globals()[f"df_recetas_{i+1}"] = df
        
    else:
        print(f"Error en la solicitud {i+1}: {response.status_code}")

# Mostrar el primer DataFrame como ejemplo
df_recetas_1.head()
# Out:
# Solicitud 1 exitosa!
# Solicitud 2 exitosa!
# Solicitud 3 exitosa!
# Solicitud 4 exitosa!
# Solicitud 5 exitosa!
#                                        title  \
# 0              Tarta de chocolate SIN AZUCAR
# 1     Cañas de chocolate con crema pastelera
# 2          Crema de calabacín con gorgonzola
# 3    Tronco de pimientos con queso y  nueces
# 4  Arroz largo salteado con verduras y huevo
#
#                                     niceName                category  \
# 0              tarta-de-chocolate-sin-azucar     Dulces y repostería
# 1     canas-de-chocolate-con-crema-pastelera     Dulces y repostería
# 2          crema-de-calabacin-con-gorgonzola  Cremas, caldos y sopas
# 3     tronco-de-pimientos-con-queso-y-nueces      Aperitivos y tapas
# 4  arroz-largo-salteado-con-verduras-y-huevo                 Arroces
#
#    totalTime  difficulty  price  \
# 0  10.000000           2      2
# 1  64.333333           1      0
# 2  30.000000           1      1
# 3  27.250000           1      1
# 4  46.500000           1      1
#
#                                                                                                                                                                                                                                                                                              ingredients  \
# 0  Dátiles (previamente remojados 1 hora) (150 gr), Agua del remojo de Datiles (40 gr), Nueces (150 gr), Aceite (1 tbsp), Leche de coco en lata (1 lata entera) (400 gr), Sal (1 pch), Harina (200 gr), Chocolate negro 70-85% de cacao (300 gr), Hojas de gelatina hidratadas (3 u), Frambuesa (150 gr)
# 1                                                                                                                                                                 Leche (250 ml), Vaina de vainilla (1 u), Azúcar (60 u), Maizena (25 gr), Yema de huevo (250 gr), Hojaldre (250 gr), Chocolate (200 gr)
# 2                                                                                                                                             Aceite de oliva virgen extra (30 gr), Calabacín (600 gr), Puerro (50 gr), Patata (300 gr), Caldo de pollo (450 gr), Queso Gorgonzola (100 gr), Sal (1 tsp)
# 3                                                                                                                    Claras de huevo (2 u), Sal (1 pch), Yemas de huevo (2 u), Pimientos (150 gr), Harina (100 gr), Levadura (0.5 scht), Nueces (60 gr), Queso (250 gr), Nueces (60 gr), Rúcula (100 gr)
# 4                                                                                        Agua (1000 gr), Sal (2 pch), Aceite (10 gr), Ajos (2 u), Arroz largo (125 gr), Aceite Oliva (30 gr), Cebolla (100 gr), Zanahoria (100 gr), Pimiento verde y rojo (120 gr), Salsa de soja (1 tsp), Huevo L (2 u)
#
#    steps  \
# 0      5
# 1     10
# 2      5
# 3     10
# 4      2
#
#                                                                                                                                                                                                                                                 tags  \
# 0                                                                                                                                 Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Navidad, Ocasiones/Celebraciones
# 1
# 2                                                                                                                                                                                        Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 3  Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Aniversarios, Ocasiones/Celebraciones, Ocasiones/Navidad, Ocasiones/Pascua, Ocasiones/San Valentín, Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 4                                                                                                                                                           Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Recetario/Mycook
#
#          group_name  \
# 0  Base de la tarta
# 1   Crema pastelera
# 2   Plato principal
# 3   Plato principal
# 4       Cocer arroz
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         group_steps
# 0  Forrarmos un molde con papel vegetal (papel de horno). Yo he utilizado un molde de 18 cm. Si usas uno más grande ten en cuenta que la tarta no te quedará tan alta. A continuación preparamos el sirope de dátil que vamos a utilizar para endulzar el relleno. Para ello trituramos un tercio de los dátiles (50 gr) con el agua y trituramos hasta conseguir una textura de sirope. Reservamos., Para preparar la base de la tarta trituramos las nueces con el resto de los dátiles (100 gr), y el aceite  hasta conseguir una pasta gruesa. La repartimos en el fondo del molde y vamos compactando con una cuchara. Reservamos en el congelador., Trituramos el resto de los ingredientes menos el chocolate hasta conseguir una crema fina. Si no queda crema, añadir más harina., Añadimos el chocolate troceado, el agar-agar y programamos 5 minutos a 40º en velocidad 3. Dejamos templar y lo vertemos en el molde que teníamos reservado en el congelador., Refrigeramos en la nevera unas 4 horas y decoramos con frambuesas o los frutos rojos que más nos gusten.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                         Empezamos preparando la crema pastelera para que Infusionen bien los ingredientes, Mezclamos el azúcar y la maizena, Añadir las yemas de huevo, Añadir la leche con vainilla. Retirar las vainas antes de añadir., Rellenar una manga pastelera con la crema pastelera tibia.\nY cortamos una masa de hojaldre en 6 rectángulos, Añadir la crema pastelera, Cerramos una parte del hojaldre dejando una solapa y pincelamos con huevo o con leche, Cerramos la caña y ponemos la parte abierta en la parte de abajo y las pincelamos de nuevo y las horneamos., Dejamos enfriar por completo, Bañar con chocolate fundido
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Calentar el Aceite de Oliva Virgen Extra, Añadir el calabacín lavado y cortado así como el puerro, Añadir la patata pelada, lavada y cortada., Añadir el caldo de pollo y dejar cocer., Añadir el queso gorgonzola y la sal y triturar.\nSi os gusta más fina la crema poner otro golpe más de turbo
# 3                                                                                                              precalentar el horno a 160º, colocar la paleta mezcladora en el vaso , incorporar las claras de huevo ,  una pizca de sal ,Reservar en un bol, retirar las claras de huevo , en un bol ,  no hace falta limpiar el vaso ,  incorporar las yemas de huevo , los pimientos escurridos , trituramos, añadimos la harina con la levadura,, incorporamos la mezcla de pimientos con las claras y mezclamos  con suavidad, vertemos la masa en la placa de horno forrada con papel sulfurizado , y horneamos 10 minutos a 160º, una vez horneado , retiramos la plancha de bizcocho ,despegamos el papel ,y la enrollamos en un paño , mientras preparamos el relleno, con el vaso limpio , trituramos las de las nueces, extendemos el bizcocho, y lo rellenamos  con el queso, las nueces picadas ,y la rúcula ,  dejar reposar en el frigo, a la hora de servir cortarlo en rodajas y servir, con  nueces y rúcula aliñada con un poco de vinagre sal y aceite de oliva
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Calentar agua con aceite y sal, Añade el arroz y los ajos

# %%
df_recetas_1["title"]
# Out:
# 0                   Tarta de chocolate SIN AZUCAR
# 1          Cañas de chocolate con crema pastelera
# 2               Crema de calabacín con gorgonzola
# 3         Tronco de pimientos con queso y  nueces
# 4       Arroz largo salteado con verduras y huevo
#                           ...
# 1995                              Arroz con leche
# 1996                Puré calabaza y quesitos Nika
# 1997                         Natillas con galleta
# 1998       Hojaldre con almendras relleno de nata
# 1999                               Tarta de quesu
# Name: title, Length: 2000, dtype: object

# %%
df_recetas_1.head(20)
# Out:
#                                           title  \
# 0                 Tarta de chocolate SIN AZUCAR
# 1        Cañas de chocolate con crema pastelera
# 2             Crema de calabacín con gorgonzola
# 3       Tronco de pimientos con queso y  nueces
# 4     Arroz largo salteado con verduras y huevo
# 5                       Guiso de porotos verdes
# 6                    Relleno para tarta de atún
# 7                                Galletas de té
# 8                         Bolognesa para pastas
# 9           Guiso de zapallo italiano (sofrito)
# 10          Gazpacho manchego con pollo y setas
# 11                               Pastel japonés
# 12                          Pad thai (My style)
# 13  Crema de calabacín con un toque de jalapeño
# 14                       Pisto manchego "light"
# 15                     Barritas de frutos secos
# 16           Bolas de mantequilla de maní snack
# 17    Snack bolitas energéticas de frutos secos
# 18                 Wraps con verduras salteadas
# 19                        Porotos granados Next
#
#                                        niceName                category  \
# 0                 tarta-de-chocolate-sin-azucar     Dulces y repostería
# 1        canas-de-chocolate-con-crema-pastelera     Dulces y repostería
# 2             crema-de-calabacin-con-gorgonzola  Cremas, caldos y sopas
# 3        tronco-de-pimientos-con-queso-y-nueces      Aperitivos y tapas
# 4     arroz-largo-salteado-con-verduras-y-huevo                 Arroces
# 5                       guiso-de-porotos-verdes   Verduras y hortalizas
# 6                    relleno-para-tarta-de-atun     Pescados y mariscos
# 7                                galletas-de-te     Dulces y repostería
# 8                         bolognesa-para-pastas   Salsas y guarniciones
# 9            guiso-de-zapallo-italiano--sofrito   Verduras y hortalizas
# 10          gazpacho-manchego-con-pollo-y-setas           Carnes y aves
# 11                               pastel-japones     Dulces y repostería
# 12                           pad-thai--my-style                   Pasta
# 13  crema-de-calabacin-con-un-toque-de-jalapeno  Cremas, caldos y sopas
# 14                        pisto-manchego--light   Salsas y guarniciones
# 15                     barritas-de-frutos-secos     Dulces y repostería
# 16              snack-mantequilla-de-mani-balls     Dulces y repostería
# 17       snack-bolitas-energeticas-frutos-secos     Dulces y repostería
# 18                 wraps-con-verduras-salteadas   Verduras y hortalizas
# 19                        porotos-granados-next     Potajes y legumbres
#
#     totalTime  difficulty  price  \
# 0   10.000000           2      2
# 1   64.333333           1      0
# 2   30.000000           1      1
# 3   27.250000           1      1
# 4   46.500000           1      1
# 5   38.000000           0      1
# 6   10.500000           1      2
# 7   15.083333           1      1
# 8   25.000000           0      2
# 9   31.000000           0      1
# 10   5.000000           1      1
# 11   8.000000           1      1
# 12  20.666667           1      1
# 13  38.000000           1      1
# 14  86.000000           1      1
# 15  12.000000           1      1
# 16   1.000000           1      1
# 17   2.000000           1      1
# 18  13.000000           1      1
# 19  33.000000           1      1
#
#                                                                                                                                                                                                                                                                                                                                                           ingredients  \
# 0                                                               Dátiles (previamente remojados 1 hora) (150 gr), Agua del remojo de Datiles (40 gr), Nueces (150 gr), Aceite (1 tbsp), Leche de coco en lata (1 lata entera) (400 gr), Sal (1 pch), Harina (200 gr), Chocolate negro 70-85% de cacao (300 gr), Hojas de gelatina hidratadas (3 u), Frambuesa (150 gr)
# 1                                                                                                                                                                                                                              Leche (250 ml), Vaina de vainilla (1 u), Azúcar (60 u), Maizena (25 gr), Yema de huevo (250 gr), Hojaldre (250 gr), Chocolate (200 gr)
# 2                                                                                                                                                                                                          Aceite de oliva virgen extra (30 gr), Calabacín (600 gr), Puerro (50 gr), Patata (300 gr), Caldo de pollo (450 gr), Queso Gorgonzola (100 gr), Sal (1 tsp)
# 3                                                                                                                                                                                 Claras de huevo (2 u), Sal (1 pch), Yemas de huevo (2 u), Pimientos (150 gr), Harina (100 gr), Levadura (0.5 scht), Nueces (60 gr), Queso (250 gr), Nueces (60 gr), Rúcula (100 gr)
# 4                                                                                                                                                     Agua (1000 gr), Sal (2 pch), Aceite (10 gr), Ajos (2 u), Arroz largo (125 gr), Aceite Oliva (30 gr), Cebolla (100 gr), Zanahoria (100 gr), Pimiento verde y rojo (120 gr), Salsa de soja (1 tsp), Huevo L (2 u)
# 5                                                                                                                                                                                                                             Aceite (40 gr), Cebolla (150 gr), Pimentón (1 tsp), Porotos verdes (250 gr), Zapallo (250 gr), Sal (1 pch), Agua (250 gr), Choclo (1 u)
# 6                                                                                       Aceite de oliva (35 gr), Pimiento morrón (100 gr), Pimiento verde (100 gr), Cebolla (300 gr), Cebolleta (50 gr), Ajo (2 clv), Sal (1 pch), Pimienta (1 pch), Huevos (2 u), Queso rallado (100 gr), Atún al natural en conserva (350 gr), Queso untable (50 gr), Nata (100 ml)
# 7                                                                                                                                                                                                                                                            Mantequilla sin sal (50 gr), Azucar (100 gr), Huevo L (55 gr), Nesquik (25 gr), Harina de trigo (150 gr)
# 8                                                                                                                                          Aceite de oliva (40 gr), Cebolla (200 gr), Diente de ajo (1 u), Tomate (1 u), Zanahoria (1 u), Carne picada (250 gr), Sal (1 pch), Salsa de tomate (200 gr), Hojas de albahaca (4 lea), Vino tinto (1 pch), Azúcar (1 pch)
# 9                                                                                                                                                                                                            Aceite (40 gr), Cebolla (200 gr), Diente de ajo (1 u), Orégano seco (1 tsp), Zapallo italiano (1200 gr), Sal (1 pch), Pan rallado (30 gr), Queso (70 gr)
# 10                                                                                                                      Aceite (50 gr), Cebolla (80 gr), Pimiento verde y rojo (100 gr), Tomate natural de bote (100 gr), Ajo (2 clv), Pechuga de pollo troceada (300 gr), Especias (1 pkt), Sal (1 pch), Setas (250 gr), Agua (700 ml), Torta para gazpacho (175 gr)
# 11                                                                                                                                                                                                                                                                                                Yema de huevo (2 u), Harina (50 gr), Azúcar (30 gr), Leche (500 gr)
# 12
# 13                                                                                                                                                                                                               Cebolla (1 u), Puerro (1 u), Calabacines (3 u), Aceite de oliva (30 gr), Patata (1 u), Caldo de verduras (500 gr), Quesitos en porciones light (4 u)
# 14                                                                                                                                                                                                                                                                   Tomate triturado (650 gr), Cebolla (300 gr), Calabacín (230 gr), Pimientos rojo y verde (620 gr)
# 15  Semillas de lino (30 gr), Dátiles sin hueso (150 gr), Nueces al natural (100 gr), Almendras tostadas sin sal (100 gr), Cacahuetes tostados sin sal (70 gr), Pistachos sin sal (70 gr), Harina de arroz (50 gr), Copos de avena (40 gr), Bicarbonato (0.5 tsp), Levadura en polvo (1 tsp), Sal yodada (1 pch), Vainilla líquida (2 tsp), Miel (60 gr), Huevo (1 u)
# 16                                                                                                                                                                                                    Avena en hojuela (200 gr), Coco rallado (50 gr), Mantequilla de mani (200 gr), Miel (100 gr), Esencia de vainilla (1 tsp), Endulzante (2 tbsp), Nueces (200 gr)
# 17                                                                                                                                                                                                                                                                                          Datiles (300 gr), Nueces (70 gr), Almendra (70 gr), Cacao amargo (2 tbsp)
# 18                                                                                                                                                        Cebolla (1 u), Cebollin (1 u), Zanahoria (1 u), Pimenton rojo (0.5 u), Champiñon (200 gr), Sal (1 tsp), Pimienta (1 pch), Crema (100 gr), Queso parmesano (100 gr), Tortillas de tacos (8 u), Lechuga (1 u)
# 19                                                                                                                                                    Choclo (300 gr), Albahaca (12 lea), Aceite (60 gr), Cebolla (200 gr), Paprika (1 tsp), Porotos granados (500 gr), Sal (1.5 tsp), Agua (1000 gr), Zapallo camote (250 gr), Choclo degranado (80 gr), Sal (1 pch)
#
#     steps  \
# 0       5
# 1      10
# 2       5
# 3      10
# 4       2
# 5       5
# 6       5
# 7       3
# 8       6
# 9       6
# 10      5
# 11      2
# 12      1
# 13      3
# 14      4
# 15      8
# 16      2
# 17      2
# 18      3
# 19      6
#
#                                                                                                                                                                                                                                                                                           tags  \
# 0                                                                                                                                                                           Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Navidad, Ocasiones/Celebraciones
# 1
# 2                                                                                                                                                                                                                                  Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 3                                            Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Aniversarios, Ocasiones/Celebraciones, Ocasiones/Navidad, Ocasiones/Pascua, Ocasiones/San Valentín, Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 4                                                                                                                                                                                                     Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Recetario/Mycook
# 5                                                                                                                                                                                                               Gastronomía/Suramericana/Chilena, Gastronomía/Suramericana, Dietas/Vegetariana
# 6
# 7   Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Gastronomía/Mediterránea, Gastronomía/Mediterránea/Española, Ocasiones/Aniversarios, Ocasiones/Carnaval, Ocasiones/Celebraciones, Ocasiones/Halloween, Ocasiones/Navidad, Ocasiones/Pascua, Ocasiones/San Valentín
# 8                                                                                                                                                                                                                                  Gastronomía/Mediterránea/Italiana, Gastronomía/Mediterránea
# 9                                                                                                                                                                                                                                                                           Dietas/Vegetariana
# 10                                                                                                                                                                                                                                      Estaciones/Invierno, Gastronomía/Mediterránea/Española
# 11                                                                                                                                                                                                                                         Gastronomía/Asiática/Japonesa, Gastronomía/Asiática
# 12                                                                                                                                                                                                                                       Gastronomía/Asiática/Tailandesa, Gastronomía/Asiática
# 13                                                                                                                              Dietas/Baja en calorías, Dietas/Sin gluten, Dietas/Sin huevo, Estación/Verano, Estación/Primavera, Estación/Otoño, Estación/Invierno, Gastronomía/Mediterránea
# 14                                                                                                                                                                                                        Dietas/Baja en calorías, Estación/Invierno, Estación/Otoño, Gastronomía/Mediterránea
# 15                                                                                                                                                                                                                      Estación/Verano, Estación/Primavera, Estación/Otoño, Estación/Invierno
# 16
# 17
# 18
# 19
#
#           group_name  \
# 0   Base de la tarta
# 1    Crema pastelera
# 2    Plato principal
# 3    Plato principal
# 4        Cocer arroz
# 5    Plato principal
# 6    Plato principal
# 7      Hacer la Masa
# 8    Plato principal
# 9    Plato principal
# 10   Plato principal
# 11   Plato principal
# 12            Comida
# 13   Plato principal
# 14   Plato principal
# 15   Plato principal
# 16   Plato principal
# 17   Plato principal
# 18   Plato principal
# 19   Plato principal
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          group_steps
# 0   Forrarmos un molde con papel vegetal (papel de horno). Yo he utilizado un molde de 18 cm. Si usas uno más grande ten en cuenta que la tarta no te quedará tan alta. A continuación preparamos el sirope de dátil que vamos a utilizar para endulzar el relleno. Para ello trituramos un tercio de los dátiles (50 gr) con el agua y trituramos hasta conseguir una textura de sirope. Reservamos., Para preparar la base de la tarta trituramos las nueces con el resto de los dátiles (100 gr), y el aceite  hasta conseguir una pasta gruesa. La repartimos en el fondo del molde y vamos compactando con una cuchara. Reservamos en el congelador., Trituramos el resto de los ingredientes menos el chocolate hasta conseguir una crema fina. Si no queda crema, añadir más harina., Añadimos el chocolate troceado, el agar-agar y programamos 5 minutos a 40º en velocidad 3. Dejamos templar y lo vertemos en el molde que teníamos reservado en el congelador., Refrigeramos en la nevera unas 4 horas y decoramos con frambuesas o los frutos rojos que más nos gusten.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                          Empezamos preparando la crema pastelera para que Infusionen bien los ingredientes, Mezclamos el azúcar y la maizena, Añadir las yemas de huevo, Añadir la leche con vainilla. Retirar las vainas antes de añadir., Rellenar una manga pastelera con la crema pastelera tibia.\nY cortamos una masa de hojaldre en 6 rectángulos, Añadir la crema pastelera, Cerramos una parte del hojaldre dejando una solapa y pincelamos con huevo o con leche, Cerramos la caña y ponemos la parte abierta en la parte de abajo y las pincelamos de nuevo y las horneamos., Dejamos enfriar por completo, Bañar con chocolate fundido
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Calentar el Aceite de Oliva Virgen Extra, Añadir el calabacín lavado y cortado así como el puerro, Añadir la patata pelada, lavada y cortada., Añadir el caldo de pollo y dejar cocer., Añadir el queso gorgonzola y la sal y triturar.\nSi os gusta más fina la crema poner otro golpe más de turbo
# 3                                                                                                               precalentar el horno a 160º, colocar la paleta mezcladora en el vaso , incorporar las claras de huevo ,  una pizca de sal ,Reservar en un bol, retirar las claras de huevo , en un bol ,  no hace falta limpiar el vaso ,  incorporar las yemas de huevo , los pimientos escurridos , trituramos, añadimos la harina con la levadura,, incorporamos la mezcla de pimientos con las claras y mezclamos  con suavidad, vertemos la masa en la placa de horno forrada con papel sulfurizado , y horneamos 10 minutos a 160º, una vez horneado , retiramos la plancha de bizcocho ,despegamos el papel ,y la enrollamos en un paño , mientras preparamos el relleno, con el vaso limpio , trituramos las de las nueces, extendemos el bizcocho, y lo rellenamos  con el queso, las nueces picadas ,y la rúcula ,  dejar reposar en el frigo, a la hora de servir cortarlo en rodajas y servir, con  nueces y rúcula aliñada con un poco de vinagre sal y aceite de oliva
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Calentar agua con aceite y sal, Añade el arroz y los ajos
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Calentar aceite, Agregar cebolla cortada en cuartos., Agregar pimentón en polvo, Insertar paleta mezcladora, agregar los porotos verdes cortados en cuadros, el zapallo cortado en cuadros, sal a gusto y agua caliente., Agregar choclo picado y agregar agua.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Calentar el aceite, Agregar los pimientos y la cebolla y sofreimos hasta que esté tierno, Agregar el resto de las verduras, Si se desean picar mas las verduras, hacer este paso, sino SALTARLO y seguir con el siguiente, Sazonar a gusto y agregar el resto de ingredientes. Mezclar y ya está listo para poner sobre una masa de tarta o empanadilla
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Añadir 50 g. de Mantequilla sin Sal en la Jarra., Añadir 100 g. de Azúcar y 1 Huevo L., (también se le puede echar Nesquik para que tenga un sabor a chocolate), mezclar todo muy bien., Añadimos 150 g. de Harina de Trigo y mezclar todo.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Calentar aceite de oliva, Agregar cebolla y ajo, Agregar tomate y zanahoria (opcional), Bajar los ingredientes de la pared y aplicar un turbo, Agregar carne molida y sal, Agregar salsa de tomates, hojas de albahaca frescas y vino tinto.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Agregar 40 gramos de aceite, Agregar cebolla cortada en cuartos y un diente de ajo, Agregar orégano, Agregar 600 gr. de zapallo italiano cortado en cuadros y sal., Agregar la otra parte del zapallo italiano., Agregar pan rallado y queso.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   sofreír aceite con cebolla, pimiento rojo y verde,  tomate natural y ajo, Sofrito pechuga de pollo troceado y especies preparado para gazpacho (pimienta negra, pebrella, tomillo, clavo y nuez moscada), Introducir setas cortadas a laminas, Hervir  toda la mezcla, Añadir torta de gazpacho
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Añade en la Jarra los ingredientes, Trasvasar a un recipiente (tupper de cristal) y dejarlo en la nevera al menos 3h
# 12
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Pelamos y lavamos la cebolla y el puerro. Lavamos los calabacines, les quitamos los extremos, pero no los pelamos. Cortamos la cebolla en cuartos, el puerro en trozos grandes y los calabacines en rodajas grandes. Añadimos todo a la jarra junto con el aceite de oliva., Añade una patata grande cortada en trozos no muy grandes junto con el caldo de verduras o el agua. Coloca la tapa antisalpicaduras., Añadir 4 quesitos y triturar.  \nRectificar de sal y decorar a tu gusto. \nLe he puesto unas gotitas de salsa de jalapeño pero es totalmente opcional.\nBuen provecho!
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Añadir 100 gramos de tomate triturado y lo sofreímos, A continuación pondremos la cebolla a sofreír, Añadimos el resto del tomate, Añadimos el calabacín (rallado a la juliana) y los pimientos
# 15                                                                                                                                                                                                                                                                                                                 Forra con papel de cocina una fuente de horno de 25x25 cm. aproximadamente. Precalienta el horno a 180º, Vierte las semillas de lino al vaso y tritura., Añade los dátiles., Agrega las nueces, las almendras, los cacahuetes y los pistachos., Incorpora la harina de arroz, los copos de avena, el bicarbonato, la levadura, la sal, la vainilla líquida, la miel y el huevo., Vierte la mezcla al molde y procura que quede uniforme (para ello puedes utilizar una cuchara mojada). Seguidamente, marca con un cuchillo el tamaño que tendrán las barritas., Hornea hasta que la superficie esté dorada (25-30 min aproximadamente). Déja enfriar la mezcla en el molde unos 30-40 min., Desmolda y corta las barritas. Guárdalas en un recipiente hermético.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Agregar los ingredientes y procesar, Armar bolitas y refrigerar. si la masa necesita estar más pegote, agregar un poco de miel y mojarse las manos con agua para manipular.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Agregar los ingredientes a la jarra y procesar., armar bolitas con la masa y mantener refrigerada.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Insertar la paleta mezcladora y agregar todas las verduras con el aceite., agregar la crema y queso, dejar enfriar la salsa en el refrigerador y luego armar los wraps con lechuga salsa de verduras y lo que más te guste.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Agregar a la jarra la albahaca y choclo. Triturar y reservar en un recipiente., enjuagar la jarra, luego agregar el aceite, cebolla y paprika. Sofreir., triturar con 1 turbo., Insertar la paleta mezcladora y agregar los porotos y el agua y la sal., agregar el zapallo en cubitos y el choclo degranado, Añadir el choclo triturado reservado, sacar el vaso dosificador para que evapore.

# %%
df_list = [df_recetas_1, df_recetas_2, df_recetas_3, df_recetas_4, df_recetas_5]

# Concatenar los 5 DataFrames en uno solo
df_recetas_total = pd.concat(df_list, ignore_index=True)

# Mostrar una vista previa del DataFrame resultante
print(df_recetas_total.head())
print("\nNúmero de filas y columnas en el DataFrame concatenado:", df_recetas_total.shape)
# Out:
#                                        title  \
# 0              Tarta de chocolate SIN AZUCAR
# 1     Cañas de chocolate con crema pastelera
# 2          Crema de calabacín con gorgonzola
# 3    Tronco de pimientos con queso y  nueces
# 4  Arroz largo salteado con verduras y huevo
#
#                                     niceName                category  \
# 0              tarta-de-chocolate-sin-azucar     Dulces y repostería
# 1     canas-de-chocolate-con-crema-pastelera     Dulces y repostería
# 2          crema-de-calabacin-con-gorgonzola  Cremas, caldos y sopas
# 3     tronco-de-pimientos-con-queso-y-nueces      Aperitivos y tapas
# 4  arroz-largo-salteado-con-verduras-y-huevo                 Arroces
#
#    totalTime  difficulty  price  \
# 0  10.000000           2      2
# 1  64.333333           1      0
# 2  30.000000           1      1
# 3  27.250000           1      1
# 4  46.500000           1      1
#
#                                                                                                                                                                                                                                                                                              ingredients  \
# 0  Dátiles (previamente remojados 1 hora) (150 gr), Agua del remojo de Datiles (40 gr), Nueces (150 gr), Aceite (1 tbsp), Leche de coco en lata (1 lata entera) (400 gr), Sal (1 pch), Harina (200 gr), Chocolate negro 70-85% de cacao (300 gr), Hojas de gelatina hidratadas (3 u), Frambuesa (150 gr)
# 1                                                                                                                                                                 Leche (250 ml), Vaina de vainilla (1 u), Azúcar (60 u), Maizena (25 gr), Yema de huevo (250 gr), Hojaldre (250 gr), Chocolate (200 gr)
# 2                                                                                                                                             Aceite de oliva virgen extra (30 gr), Calabacín (600 gr), Puerro (50 gr), Patata (300 gr), Caldo de pollo (450 gr), Queso Gorgonzola (100 gr), Sal (1 tsp)
# 3                                                                                                                    Claras de huevo (2 u), Sal (1 pch), Yemas de huevo (2 u), Pimientos (150 gr), Harina (100 gr), Levadura (0.5 scht), Nueces (60 gr), Queso (250 gr), Nueces (60 gr), Rúcula (100 gr)
# 4                                                                                        Agua (1000 gr), Sal (2 pch), Aceite (10 gr), Ajos (2 u), Arroz largo (125 gr), Aceite Oliva (30 gr), Cebolla (100 gr), Zanahoria (100 gr), Pimiento verde y rojo (120 gr), Salsa de soja (1 tsp), Huevo L (2 u)
#
#    steps  \
# 0      5
# 1     10
# 2      5
# 3     10
# 4      2
#
#                                                                                                                                                                                                                                                 tags  \
# 0                                                                                                                                 Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Navidad, Ocasiones/Celebraciones
# 1
# 2                                                                                                                                                                                        Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 3  Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Ocasiones/Aniversarios, Ocasiones/Celebraciones, Ocasiones/Navidad, Ocasiones/Pascua, Ocasiones/San Valentín, Gastronomía/Mediterránea/Española, Gastronomía/Mediterránea
# 4                                                                                                                                                           Estación/Invierno, Estación/Otoño, Estación/Primavera, Estación/Verano, Recetario/Mycook
#
#          group_name  \
# 0  Base de la tarta
# 1   Crema pastelera
# 2   Plato principal
# 3   Plato principal
# 4       Cocer arroz
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         group_steps
# 0  Forrarmos un molde con papel vegetal (papel de horno). Yo he utilizado un molde de 18 cm. Si usas uno más grande ten en cuenta que la tarta no te quedará tan alta. A continuación preparamos el sirope de dátil que vamos a utilizar para endulzar el relleno. Para ello trituramos un tercio de los dátiles (50 gr) con el agua y trituramos hasta conseguir una textura de sirope. Reservamos., Para preparar la base de la tarta trituramos las nueces con el resto de los dátiles (100 gr), y el aceite  hasta conseguir una pasta gruesa. La repartimos en el fondo del molde y vamos compactando con una cuchara. Reservamos en el congelador., Trituramos el resto de los ingredientes menos el chocolate hasta conseguir una crema fina. Si no queda crema, añadir más harina., Añadimos el chocolate troceado, el agar-agar y programamos 5 minutos a 40º en velocidad 3. Dejamos templar y lo vertemos en el molde que teníamos reservado en el congelador., Refrigeramos en la nevera unas 4 horas y decoramos con frambuesas o los frutos rojos que más nos gusten.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                         Empezamos preparando la crema pastelera para que Infusionen bien los ingredientes, Mezclamos el azúcar y la maizena, Añadir las yemas de huevo, Añadir la leche con vainilla. Retirar las vainas antes de añadir., Rellenar una manga pastelera con la crema pastelera tibia.\nY cortamos una masa de hojaldre en 6 rectángulos, Añadir la crema pastelera, Cerramos una parte del hojaldre dejando una solapa y pincelamos con huevo o con leche, Cerramos la caña y ponemos la parte abierta en la parte de abajo y las pincelamos de nuevo y las horneamos., Dejamos enfriar por completo, Bañar con chocolate fundido
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Calentar el Aceite de Oliva Virgen Extra, Añadir el calabacín lavado y cortado así como el puerro, Añadir la patata pelada, lavada y cortada., Añadir el caldo de pollo y dejar cocer., Añadir el queso gorgonzola y la sal y triturar.\nSi os gusta más fina la crema poner otro golpe más de turbo
# 3                                                                                                              precalentar el horno a 160º, colocar la paleta mezcladora en el vaso , incorporar las claras de huevo ,  una pizca de sal ,Reservar en un bol, retirar las claras de huevo , en un bol ,  no hace falta limpiar el vaso ,  incorporar las yemas de huevo , los pimientos escurridos , trituramos, añadimos la harina con la levadura,, incorporamos la mezcla de pimientos con las claras y mezclamos  con suavidad, vertemos la masa en la placa de horno forrada con papel sulfurizado , y horneamos 10 minutos a 160º, una vez horneado , retiramos la plancha de bizcocho ,despegamos el papel ,y la enrollamos en un paño , mientras preparamos el relleno, con el vaso limpio , trituramos las de las nueces, extendemos el bizcocho, y lo rellenamos  con el queso, las nueces picadas ,y la rúcula ,  dejar reposar en el frigo, a la hora de servir cortarlo en rodajas y servir, con  nueces y rúcula aliñada con un poco de vinagre sal y aceite de oliva
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Calentar agua con aceite y sal, Añade el arroz y los ajos
#
# Número de filas y columnas en el DataFrame concatenado: (10000, 11)

# %%
df_full = df_recetas_total.copy()

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        10000 non-null  object
#  1   niceName     10000 non-null  object
#  2   category     10000 non-null  object
#  3   totalTime    10000 non-null  float64
#  4   difficulty   10000 non-null  int64
#  5   price        10000 non-null  int64
#  6   ingredients  10000 non-null  object
#  7   steps        10000 non-null  int64
#  8   tags         10000 non-null  object
#  9   group_name   10000 non-null  object
#  10  group_steps  10000 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 859.5+ KB

# %%
df_recetas_total["title"].drop_duplicates().sort_values(
    
)
# Out:
# 264         "Menjar blanc" con harina de arroz
# 9459                Abichuelas rapidas de bote
# 9484                      Aceite a la albahaca
# 6869                  Aceite con ajo y perejil
# 6911                          Acelga con papas
#                          ...
# 1078                   Ñoquis de papa del pepe
# 2004                          Ñoquis de patata
# 3199                         Ñoquis saludables
# 1867                  🍓 🍦 Strawberry ice-cream
# 253     🖤ARROZ CON CALAMARES EN TINTA Y GAMBAS
# Name: title, Length: 9701, dtype: object

# %%
df_recetas_total["niceName"].value
# Out:
# array(['crema-de-calabacin-con-gorgonzola',
#        'tronco-de-pimientos-con-queso-y-nueces',
#        'arroz-largo-salteado-con-verduras-y-huevo', ...,
#        'salmorejo-angel', 'bizcocho-de-naranja-y-yogur',
#        'brioche-de-crema-pastelera-y-chocolate'], dtype=object)

# %% [markdown]
# ### eliminamos "Otras"

# %%
df_recetas_total.drop(df_recetas_total[(df_recetas_total["category"] == "Funciones básicas")].index, inplace=True)

# %%
df_recetas_total.groupby("category").size().sort_values(ascending=False)
# Out:
# category
# Dulces y repostería                 2608
# Cremas, caldos y sopas               964
# Huevos y tarrinas                    863
# Carnes y aves                        747
# Verduras y hortalizas                675
# Masas                                629
# Salsas y guarniciones                570
# Aperitivos y tapas                   567
# Potajes y legumbres                  491
# Arroces                              458
# Pescados y mariscos                  373
# Pasta                                369
# Bebidas y cócteles                   275
# Papillas y alimentación infantil     131
# Sorbetes y helados                   119
# Ensaladas                             87
# Otras                                 47
# Vinagretas y aliños                   26
# dtype: int64
